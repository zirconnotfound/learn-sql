# %%
from google.cloud import bigquery
client = bigquery.Client()
dataset_ref = client.dataset("stackoverflow", project="bigquery-public-data")
dataset = client.get_dataset(dataset_ref)
# Out:
# C:\Users\ADMIN\AppData\Roaming\Python\Python312\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
table_ref = dataset_ref.table("posts_questions")
table = client.get_table(table_ref)
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#        id                                              title  \
# 0  320268          Html.ActionLink doesn’t render # properly
# 1  324003                                Primitive recursion
# 2  390605                                 While vs. Do While
# 3  413246                        Protect ASP.NET Source code
# 4  454921  Difference between "int[] myArray" and "int my...
#
#                                                 body  accepted_answer_id  \
# 0  <p>When using Html.ActionLink passing a string...                <NA>
# 1  <p>how  will i define the function 'simplify' ...                <NA>
# 2  <p>I've seen both the blocks of code in use se...              390608
# 3  <p>Im currently doing some research in how to ...                <NA>
# 4  <blockquote>\n  <p><strong>Possible Duplicate:...              454928
#
#    answer_count  comment_count community_owned_date  \
# 0             0              0                  NaT
# ...

# %%
table_ref = dataset_ref.table("posts_answers")
table = client.get_table(table_ref)
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#      id title                                               body  \
# 0    18  None  <p>For a table like this:</p>\n\n<pre><code>CR...
# 1   165  None  <p>You can use a <a href="http://sharpdevelop....
# 2  1028  None  <p>The VB code looks something like this:</p>\...
# 3  1073  None  <p>My first choice would be a dedicated heap t...
# 4  1260  None  <p>I found the answer. all you have to do is a...
#
#   accepted_answer_id answer_count  comment_count community_owned_date  \
# 0               None         None              2                  NaT
# 1               None         None              0                  NaT
# 2               None         None              0                  NaT
# 3               None         None              0                  NaT
# 4               None         None              0                  NaT
#
#                      creation_date favorite_count  \
# 0 2008-08-01 05:12:44.193000+00:00           None
# ...

# %%
query = """
    WITH joined_table AS (
        SELECT u.id AS id, a.creation_date AS a_creation_date, q.creation_date AS q_creation_date
        FROM `bigquery-public-data.stackoverflow.users` AS u
        LEFT JOIN `bigquery-public-data.stackoverflow.posts_questions` AS q
        ON u.id = q.owner_user_id
        LEFT JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
        ON u.id = a.owner_user_id
        WHERE u.creation_date >= '2019-01-01' AND u.creation_date < '2020-01-01'
    )
    SELECT id, MIN(a_creation_date) as a_creation_date, MIN(q_creation_date) as q_creation_date
    FROM joined_table
    GROUP BY id
"""
result = client.query(query).result().to_dataframe()
print(result.tail())
# Out:
#                id                  a_creation_date  \
# 1715827  12409995                              NaT
# 1715828  10900667 2020-09-06 04:15:31.983000+00:00
# 1715829  11701881                              NaT
# 1715830  11786228                              NaT
# 1715831  11256158                              NaT
#
#                          q_creation_date
# 1715827 2019-03-09 11:24:38.987000+00:00
# 1715828                              NaT
# 1715829 2019-06-26 08:23:30.837000+00:00
# 1715830 2019-07-15 11:40:29.103000+00:00
# 1715831 2019-10-25 13:48:11.827000+00:00

# %%
query = """
    SELECT owner_user_id
    FROM `bigquery-public-data.stackoverflow.posts_answers`
    WHERE EXTRACT(date FROM creation_date) = '2019-01-01'
    UNION DISTINCT
    SELECT owner_user_id
    FROM `bigquery-public-data.stackoverflow.posts_questions`
    WHERE EXTRACT(date FROM creation_date) = '2019-01-01'
"""
result = client.query(query).result().to_dataframe()
print(result.tail())
# Out:
#       owner_user_id
# 4347        1089967
# 4348        4553309
# 4349        1980359
# 4350        4151019
# 4351        3922207
